# %%
import os
from docx import Document
import re
import spacy
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd
import time
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
docs = []
path = "docs"
for dir in os.listdir(path):
    document = Document(os.path.join(path, dir))
    data = ''
    for para in document.paragraphs:
        data += " " + para.text
    docs.append(data)

# %%
class WordDOI:
    """docstring for WordDOI."""
    def __init__(self, doc):
        
        self.doc_list = doc.split(".")
        self.cleanDocList = []
        self.dataMap = {}
        self.allWords = set()
        self.deg = {}
        self.degList = []
        self.pairList = []
        self.nlp = spacy.load('en_core_web_sm', disable = ['parser', 'ner'])
        self.stop = stopwords.words('english')

    # function for text cleaning
    def textCleaner(self, doc):
        doc = re.sub("[,.']", "", doc)
        doc = [token for token in doc.split(' ') if len(re.sub("[a-zA-Z]", "", token)) <= 0]
        doc = self.nlp(" ".join(doc))
        taglist = ['RB','RBR', 'RBS','JJR','JJ','JJS','NN','NNS','VB','VBG','VBP','VBN']
        poslist = ['ADJ','ADV','NOUN','VERB']
        doc = [token.lemma_.lower() for token in doc if token.tag_ in taglist and token.pos_ in poslist]
        doc = [token for token in doc if not token in self.stop and len(token)>2]
        return doc

    # function to clean the data and store it in the object
    def cleanData(self):
        self.cleanDocList = []

        # cleaning of data
        for i, row in enumerate(self.doc_list):
            row = self.textCleaner(row)
            self.cleanDocList.append(row)

    # function to create data logs like data map, all words list and store it in the object
    def createDataLog(self, freqLmt = 1):
        self.dataMap = {}              
        self.allWords = set()           

        # creating data map and storing all words
        for i, sen in enumerate(self.cleanDocList):
            for word in sen:
                self.dataMap[word] = self.dataMap.get(word, set())
                self.dataMap[word].add(i)
                self.allWords.add(word)

        tmp_all_words = []

        # filtering words
        for word in self.allWords:
            if len(self.dataMap[word]) > freqLmt:
                tmp_all_words.append(word)

        self.allWords = set(tmp_all_words)

    # function to find DOI list and store it in the object
    def findDOI(self):
        self.deg = {}
        self.degList = []

        # calculating DOI of each word
        for word1 in self.allWords:
            tempDeg = 0
            for word2 in self.allWords:
                if word1 == word2: continue
                common = self.dataMap[word1] & self.dataMap[word2]

                if len(common) == 0: continue
                tempDeg += len(common)

            self.deg[word1] = tempDeg

        # creating DOI
        for word in self.deg:
            dg = self.deg[word]
            self.degList.append((word, dg))

        self.degList = sorted(self.degList, key=lambda x : x[1], reverse=True)

    # function to find word pairs and store it in the object
    def findPairs(self):
        self.pairList = []
        probMap = {}
        probMapPrev = {}
        wordCount = {}

        # creating count map for next word and previous word
        for i, sen in enumerate(self.cleanDocList):
            prev = " "
            for word in sen:
                if prev == " ": prev = word
                else:
                    probMap[prev] = probMap.get(prev, dict())
                    probMap[prev][word] = probMap[prev].get(word, 0) + 1

                    probMapPrev[word] = probMapPrev.get(word, dict())
                    probMapPrev[word][prev] = probMapPrev[word].get(prev, 0) + 1

                    prev = word

                wordCount[word] = wordCount.get(word, 0) + 1

        # creating probabilty map for next using count map
        for keyWord in probMap:
            for key in probMap[keyWord]:
                probMap[keyWord][key] /= wordCount[keyWord]               

        # creating probabilty map for previous word using count map
        for keyWord in probMapPrev:
            for key in probMapPrev[keyWord]:
                probMapPrev[keyWord][key] /= wordCount[keyWord]

        # creating list of pairs and calculating there relevance score
        for k1 in probMap:
            for k2 in probMap[k1]:
                degSum = (self.deg.get(k1, 0)+self.deg.get(k2, 0))
                if degSum == 0: continue

                denom = len(self.allWords)/degSum

                k1Val = probMap[k1][k2]*(self.deg.get(k1, 0)/denom)
                k2Val = probMapPrev[k2][k1]*(self.deg.get(k2, 0)/denom)

                self.pairList.append(((k1, k2), (k1Val+k2Val)))

        self.pairList = sorted(self.pairList, key=lambda x : x[1], reverse=True)

    def getTopNDOI(self, N=-1):
        if N == -1:
            return self.degList
        elif N <= len(self.degList):
            return self.degList[:N]
        else:
            print(f'{N} exceeds list size (Top {len(self.degList)} returned)')
            return self.degList
   
    def getTopNPairs(self, N=-1):
        if N == -1:
            return self.pairList
        elif N <= len(self.pairList):
            return self.pairList[:N]
        else:
            print(f'{N} exceeds list size (Top {len(self.pairList)} returned)')
            return self.pairList

    # run all the required processes and then return top N DOI and top N pairs
    def getDOI(self, NDOI=-1, NPairs=-1):
        # cleaning of data
        try:
            start_time = time.time()
            self.cleanData()
            print(f"Time taken in cleaning {int((time.time() - start_time))} seconds " )
        except Exception as e:
            print("Error while cleaning the data")
            print("Exception occured - {}".format(e))
            print("Stoping the process")
            return [], []
        
        # creating data logs
        try:
            start_time = time.time()
            self.createDataLog()
            print(f"Time taken in logging {int((time.time() - start_time))} seconds ")
        except Exception as e:
            print("Error while logging the data")
            print("Exception occured - {}".format(e))
            print("Stoping the process")
            return [], []
        
        # finding DOI
        try:
            start_time = time.time()
            self.findDOI()
            print(f"Time taken in DOI {int((time.time() - start_time))} seconds " )
        except Exception as e:
            print("Error while DOI the data")
            print("Exception occured - {}".format(e))
            print("Stoping the process")
            return [], []
        
        # finding word pairs
        try:
            start_time = time.time()
            self.findPairs()
            print(f"time taken in finding pairs {int((time.time() - start_time))} seconds " )
        except Exception as e:
            print("Error while finding pairs the data")
            print("Exception occured - {}".format(e))
            print("Stoping the process")
            return [], []
        
        return self.getTopNDOI(NDOI), self.getTopNPairs(NPairs)

# %%
ww = WordDOI(docs[0])
ww.getDOI(NDOI=1)
# Out:
# Time taken in cleaning 1 seconds
# Time taken in logging 0 seconds
# Time taken in DOI 0 seconds
# time taken in finding pairs 0 seconds
# ([('interview', 365)],
#  [(('code', 'interview'), 1190.6107142857143),
#   (('job', 'interview'), 495.6140172101449),
#   (('prepare', 'code'), 274.61680194805194),
#   (('interview', 'course'), 262.2160218253968),
#   (('course', 'prepare'), 258.66747835497836),
#   (('dynamic', 'programming'), 256.8863636363636),
#   (('course', 'learn'), 189.88095238095238),
#   (('good', 'course'), 146.7049486461251),
#   (('online', 'course'), 145.30158730158732),
#   (('prepare', 'interview'), 137.11122159090908),
#   (('programming', 'job'), 127.74471343873518),
#   (('link', 'join'), 121.76618303571428),
#   (('structure', 'algorithm'), 118.12500000000001),
#   (('join', 'course'), 115.72256944444445),
#   (('interview', 'question'), 108.5966517857143),
#   (('course', 'also'), 104.36344461697723),
#   (('datum', 'structure'), 97.03125),
#   (('access', 'course'), 96.79577380952381),
#   (('course', 'code'), 93.53083900226757),
#   (('programming', 'interview'), 91.88238636363637),
#   (('code', 'question'), 91.73405612244898),
#   (('course', 'even'), 85.90623015873015),
#   (('problem', 'code'), 85.34526466836735),
#   (('also', 'learn'), 84.05271739130436),
#   (('even', 'prepare'), 79.11272727272726),
#   (('good', 'interview'), 78.11825980392157),
#   (('interview', 'good'), 78.11825980392157),
#   (('code', 'job'), 77.38406166814553),
#   (('interview', 'company'), 75.97633928571429),
#   (('take', 'course'), 74.70019841269841),
#   (('interview', 'also'), 74.28500905797102),
#   (('course', 'good'), 73.35247432306255),
#   (('programmer', 'prepare'), 69.26298701298701),
#   (('programming', 'language'), 69.13636363636364),
#   (('crack', 'code'), 69.04438775510204),
#   (('course', 'programmer'), 67.72123015873015),
#   (('data', 'structure'), 66.515625),
#   (('programming', 'problem'), 66.29083806818181),
#   (('code', 'skill'), 64.04681122448979),
#   (('prepare', 'job'), 63.491897233201584),
#   (('previous', 'course'), 62.74464285714285),
#   (('pattern', 'code'), 62.26224489795918),
#   (('right', 'course'), 61.125396825396834),
#   (('look', 'job'), 58.14089673913044),
#   (('course', 'available'), 57.81706349206349),
#   (('code', 'problem'), 56.896843112244895),
#   (('first', 'job'), 52.94347826086957),
#   (('join', 'code'), 51.62177933673469),
#   (('topic', 'code'), 49.76237244897959),
#   (('interview', 'code'), 49.608779761904756),
#   (('question', 'programming'), 49.07475649350649),
#   (('job', 'big'), 47.826086956521735),
#   (('prepare', 'software'), 47.41883116883117),
#   (('practice', 'code'), 46.46311224489796),
#   (('computer', 'science'), 46.225),
#   (('success', 'code'), 45.672193877551024),
#   (('interview', 'even'), 45.47677083333333),
#   (('get', 'job'), 44.51059782608695),
#   (('programming', 'pattern'), 44.5),
#   (('interview', 'base'), 43.96510416666666),
#   (('knowledge', 'interview'), 40.76145833333334),
#   (('interview', 'improve'), 40.7109375),
#   (('interview', 'learn'), 40.40208333333334),
#   (('course', 'must'), 40.192460317460316),
#   (('course', 'help'), 40.05515873015873),
#   (('course', 'recommend'), 40.05515873015873),
#   (('recommend', 'course'), 40.05515873015873),
#   (('interview', 'well'), 39.86958333333334),
#   (('well', 'interview'), 39.86958333333334),
#   (('structure', 'interview'), 39.59791666666667),
#   (('code', 'programming'), 39.44732142857143),
#   (('programming', 'code'), 39.44732142857143),
#   (('course', 'year'), 38.913690476190474),
#   (('course', 'highly'), 38.913690476190474),
#   (('popular', 'course'), 38.913690476190474),
#   (('interview', 'hence'), 38.70052083333333),
#   (('graduate', 'programmer'), 38.40267857142857),
#   (('course', 'improve'), 38.32529761904762),
#   (('learn', 'course'), 37.976190476190474),
#   (('interview', 'ready'), 37.4),
#   (('interview', 'focus'), 37.4),
#   (('ready', 'interview'), 37.4),
#   (('course', 'choose'), 36.91541666666667),
#   (('choose', 'course'), 36.91541666666667),
#   (('interview', 'know'), 36.910243055555554),
#   (('code', 'technology'), 36.728188775510205),
#   (('course', 'eventually'), 36.374900793650795),
#   (('deal', 'code'), 36.17482993197279),
#   (('interview', 'thing'), 35.65416666666667),
#   (('pattern', 'course'), 35.61051587301587),
#   (('get', 'interview'), 35.29985119047619),
#   (('course', 'find'), 34.09295634920635),
#   (('problem', 'interview'), 34.051822916666666),
#   (('interview', 'previous'), 33.5359375),
#   (('design', 'course'), 33.43055555555555),
#   (('course', 'thing'), 33.42078373015873),
#   (('improve', 'code'), 33.25752551020408),
#   (('get', 'access'), 33.23544642857143),
#   (('good', 'code'), 32.95873349339736),
#   (('course', 'teach'), 32.59414682539683),
#   (('prepare', 'programming'), 32.263920454545456),
#   (('problem', 'course'), 31.821192956349208),
#   (('course', 'look'), 31.60535714285714),
#   (('interview', 'preparation'), 31.563541666666666),
#   (('course', 'want'), 31.228670634920633),
#   (('code', 'pattern'), 31.13112244897959),
#   (('interview', 'join'), 31.069010416666668),
#   (('interview', 'lack'), 30.991145833333334),
#   (('interview', 'give'), 30.778124999999996),
#   (('tech', 'code'), 30.195663265306123),
#   (('interview', 'solve'), 30.1328125),
#   (('interview', 'kind'), 29.799999999999997),
#   (('learn', 'solve'), 29.686805555555555),
#   (('get', 'code'), 29.453954081632652),
#   (('code', 'get'), 29.453954081632652),
#   (('knowledge', 'datum'), 29.4),
#   (('course', 'list'), 29.16984126984127),
#   (('attend', 'code'), 29.116581632653066),
#   (('course', 'useful'), 28.908531746031745),
#   (('short', 'course'), 28.908531746031745),
#   (('course', 'give'), 28.688988095238095),
#   (('teach', 'code'), 28.47563775510204),
#   (('code', 'boot'), 28.446938775510205),
#   (('join', 'dynamic'), 28.1421875),
#   (('course', 'level'), 28.003125),
#   (('kind', 'course'), 27.75238095238095),
#   (('science', 'graduate'), 27.735),
#   (('course', 'difficult'), 27.686011904761905),
#   (('many', 'code'), 27.595408163265304),
#   (('require', 'interview'), 27.22083333333333),
#   (('collection', 'code'), 26.998086734693878),
#   (('lot', 'code'), 26.974489795918366),
#   (('course', 'free'), 26.90486111111111),
#   (('code', 'complexity'), 25.948214285714286),
#   (('chance', 'interview'), 25.4640625),
#   (('also', 'prepare'), 25.410375494071143),
#   (('course', 'particularly'), 25.259722222222223),
#   (('common', 'question'), 25.202380952380956),
#   (('structure', 'prepare'), 25.099005681818184),
#   (('give', 'code'), 25.051658163265305),
#   (('code', 'solve'), 24.909948979591835),
#   (('solve', 'code'), 24.909948979591835),
#   (('fail', 'code'), 24.904591836734696),
#   (('query', 'question'), 24.86279761904762),
#   (('knowledge', 'prepare'), 24.663849431818186),
#   (('code', 'data'), 24.63303571428571),
#   (('choose', 'right'), 24.603749999999998),
#   (('course', 'educative'), 24.387301587301586),
#   (('prepare', 'question'), 24.370670995670995),
#   (('question', 'prepare'), 24.370670995670995),
#   (('programming', 'algorithm'), 23.89090909090909),
#   (('programming', 'software'), 23.878125),
#   (('job', 'much'), 23.87391304347826),
#   (('difficult', 'code'), 23.8672193877551),
#   (('interview', 'see'), 23.72),
#   (('software', 'job'), 23.560248447204966),
#   (('algorithm', 'job'), 23.51759510869565),
#   (('interview', 'create'), 23.506770833333334),
#   (('code', 'practice'), 23.23155612244898),
#   (('programming', 'improve'), 23.096875),
#   (('software', 'development'), 22.30892857142857),
#   (('development', 'job'), 22.26657608695652),
#   (('solve', 'problem'), 22.03046875),
#   (('course', 'late'), 21.907242063492063),
#   (('use', 'code'), 21.78877551020408),
#   (('take', 'job'), 21.73913043478261),
#   (('learn', 'analyze'), 21.65833333333333),
#   (('important', 'prepare'), 21.38383838383838),
#   (('programming', 'find'), 21.268465909090907),
#   (('good', 'learn'), 21.25531045751634),
#   (('code', 'fast'), 21.135714285714286),
#   (('overall', 'good'), 21.01960784313726),
#   (('find', 'job'), 20.97065217391304),
#   (('learn', 'dynamic'), 20.611111111111107),
#   (('developer', 'job'), 20.27263198757764),
#   (('tech', 'company'), 19.804017857142856),
#   (('question', 'ask'), 19.78095238095238),
#   (('look', 'programming'), 19.674242424242422),
#   (('good', 'even'), 19.55154411764706),
#   (('lot', 'programming'), 19.43474025974026),
#   (('job', 'want'), 19.413509316770185),
#   (('prepare', 'next'), 19.339772727272727),
#   (('next', 'job'), 19.25978260869565),
#   (('job', 'dream'), 19.164402173913043),
#   (('common', 'programming'), 18.916193181818183),
#   (('good', 'knowledge'), 18.514889705882354),
#   (('similar', 'problem'), 18.314843749999998),
#   (('algorithm', 'also'), 18.061345108695654),
#   (('list', 'prepare'), 17.985984848484847),
#   (('prepare', 'especially'), 17.981818181818184),
#   (('give', 'programming'), 17.82992424242424),
#   (('know', 'learn'), 17.807291666666664),
#   (('company', 'learn'), 17.738343253968253),
#   (('prepare', 'hard'), 17.289204545454545),
#   (('also', 'well'), 17.22451086956522),
#   (('job', 'never'), 17.218070652173914),
#   (('write', 'code'), 17.117346938775512),
#   (('big', 'question'), 16.995238095238093),
#   (('also', 'get'), 16.98037655279503),
#   (('knowledge', 'dynamic'), 16.940625000000004),
#   (('learn', 'important'), 16.911458333333332),
#   (('level', 'programming'), 16.892329545454547),
#   (('really', 'good'), 16.689411764705884),
#   (('question', 'need'), 16.492261904761904),
#   (('skill', 'also'), 16.47554347826087),
#   (('learn', 'find'), 16.46701388888889),
#   (('must', 'want'), 16.291964285714286),
#   (('want', 'crack'), 16.291964285714286),
#   (('good', 'online'), 16.080882352941178),
#   (('question', 'really'), 16.065059523809524),
#   (('algorithm', 'knowledge'), 15.923437499999999),
#   (('even', 'get'), 15.911160714285714),
#   (('question', 'one'), 15.858333333333334),
#   (('algorithm', 'algorithm'), 15.768749999999999),
#   (('job', 'start'), 15.734782608695651),
#   (('learn', 'experience'), 15.714236111111111),
#   (('boot', 'camp'), 15.625),
#   (('knowledge', 'need'), 15.37890625),
#   (('know', 'dynamic'), 15.353124999999999),
#   (('important', 'topic'), 15.3125),
#   (('job', 'offer'), 15.232608695652175),
#   (('ask', 'job'), 15.232608695652175),
#   (('want', 'learn'), 15.21701388888889),
#   (('highly', 'recommend'), 15.125),
#   (('learn', 'lot'), 14.97470238095238),
#   (('memory', 'prepare'), 14.915151515151518),
#   (('also', 'teach'), 14.908559782608696),
#   (('get', 'first'), 14.886160714285712),
#   (('science', 'question'), 14.85982142857143),
#   (('join', 'good'), 14.781755514705882),
#   (('junior', 'developer'), 14.6875),
#   (('question', 'find'), 14.672619047619047),
#   (('design', 'question'), 14.635416666666666),
#   (('even', 'know'), 14.535555555555554),
#   (('need', 'get'), 14.442410714285714),
#   (('big', 'problem'), 14.132421874999999),
#   (('much', 'programmer'), 14.100000000000001),
#   (('also', 'share'), 14.070923913043478),
#   (('look', 'good'), 14.049019607843135),
#   (('question', 'advance'), 14.03095238095238),
#   (('need', 'deal'), 13.883333333333331),
#   (('interview', 'bootcamp'), 13.877604166666666),
#   (('interview', 'guide'), 13.877604166666666),
#   (('interview', 'call'), 13.877604166666666),
#   (('interview', 'becuase'), 13.877604166666666),
#   (('interview', 'ability'), 13.877604166666666),
#   (('interview', 'thank'), 13.877604166666666),
#   (('aspect', 'interview'), 13.877604166666666),
#   (('onsite', 'interview'), 13.877604166666666),
#   (('hour', 'interview'), 13.877604166666666),
#   (('brush', 'interview'), 13.877604166666666),
#   (('mock', 'interview'), 13.877604166666666),
#   (('sample', 'interview'), 13.877604166666666),
#   (('real', 'interview'), 13.877604166666666),
#   (('successfully', 'interview'), 13.877604166666666),
#   (('well', 'programmer'), 13.875178571428574),
#   (('need', 'know'), 13.82777777777778),
#   (('improve', 'algorithm'), 13.6921875),
#   (('algorithm', 'help'), 13.6875),
#   (('choose', 'programmer'), 13.602857142857141),
#   (('algorithm', 'important'), 13.55329861111111),
#   (('share', 'good'), 13.503921568627451),
#   (('really', 'need'), 13.427499999999998),
#   (('master', 'learn'), 13.399652777777778),
#   (('question', 'easy'), 13.381696428571427),
#   (('algorithm', 'one'), 13.325520833333332),
#   (('recommend', 'get'), 13.23482142857143),
#   (('need', 'choose'), 13.162500000000001),
#   (('improve', 'knowledge'), 13.09453125),
#   (('popular', 'dynamic'), 13.040625),
#   (('problem', 'base'), 13.025390625),
#   (('teach', 'dynamic'), 13.0),
#   (('structure', 'solve'), 12.9890625),
#   (('solve', 'question'), 12.971428571428572),
#   (('one', 'need'), 12.808333333333332),
#   (('book', 'prepare'), 12.8),
#   (('question', 'common'), 12.601190476190478),
#   (('question', 'right'), 12.569345238095238),
#   (('question', 'include'), 12.43139880952381),
#   (('programmer', 'developer'), 12.384821428571428),
#   (('know', 'deal'), 12.374305555555555),
#   (('good', 'collection'), 12.370955882352941),
#   (('developer', 'even'), 12.36232142857143),
#   (('course', 'cheap'), 12.362003968253967),
#   (('course', 'site'), 12.362003968253967),
#   (('course', 'focused'), 12.362003968253967),
#   (('course', 'enough'), 12.362003968253967),
#   (('course', 'add'), 12.362003968253967),
#   (('course', 'fresh'), 12.362003968253967),
#   (('course', 'climb'), 12.362003968253967),
#   (('course', 'around'), 12.362003968253967),
#   (('course', 'try'), 12.362003968253967),
#   (('course', 'step'), 12.362003968253967),
#   (('training', 'course'), 12.362003968253967),
#   (('ideal', 'course'), 12.362003968253967),
#   (('fantastic', 'course'), 12.362003968253967),
#   (('couple', 'course'), 12.362003968253967),
#   (('school', 'course'), 12.362003968253967),
#   (('quality', 'course'), 12.362003968253967),
#   (('future', 'course'), 12.362003968253967),
#   (('cover', 'course'), 12.362003968253967),
#   (('modern', 'course'), 12.362003968253967),
#   (('watch', 'course'), 12.362003968253967),
#   (('time', 'course'), 12.362003968253967),
#   (('third', 'course'), 12.362003968253967),
#   (('follow', 'course'), 12.362003968253967),
#   (('company', 'big'), 12.342857142857143),
#   (('well', 'know'), 12.186805555555555),
#   (('knowledge', 'take'), 11.91484375),
#   (('useful', 'also'), 11.864130434782608),
#   (('design', 'software'), 11.808035714285714),
#   (('easy', 'master'), 11.78125),
#   (('programmer', 'want'), 11.75),
#   (('programmer', 'lot'), 11.541964285714286),
#   (('question', 'interviewer'), 11.396279761904763),
#   (('learn', 'work'), 11.34201388888889),
#   (('many', 'programmer'), 11.264464285714286),
#   (('solve', 'big'), 11.25),
#   (('also', 'free'), 11.234782608695653),
#   (('need', 'lot'), 11.228571428571428),
#   (('really', 'well'), 11.045000000000002),
#   (('problem', 'easy'), 11.032291666666666),
#   (('also', 'use'), 11.00151397515528),
#   (('code', 'run'), 10.950127551020406),
#   (('code', 'sense'), 10.950127551020406),
#   (('code', 'challenge'), 10.950127551020406),
#   (('code', 'school'), 10.950127551020406),
#   (('code', 'minute'), 10.950127551020406),
#   (('reduce', 'code'), 10.950127551020406),
#   (('develop', 'code'), 10.950127551020406),
#   (('ultimate', 'code'), 10.950127551020406),
#   (('engineering', 'code'), 10.950127551020406),
#   (('question', 'different'), 10.88809523809524),
#   (('solve', 'know'), 10.829166666666666),
#   (('well', 'deal'), 10.796666666666667),
#   (('technology', 'company'), 10.782589285714284),
#   (('experience', 'software'), 10.746428571428572),
#   (('important', 'design'), 10.736607142857142),
#   (('design', 'important'), 10.736607142857142),
#   (('list', 'algorithm'), 10.611979166666666),
#   (('lot', 'software'), 10.608035714285712),
#   (('important', 'skill'), 10.589583333333334),
#   (('big', 'technology'), 10.546875),
#   (('article', 'good'), 10.545588235294117),
#   (('solve', 'really'), 10.530000000000001),
#   (('software', 'easy'), 10.515625),
#   (('important', 'computer'), 10.506805555555555),
#   (('topic', 'dynamic'), 10.40625),
#   (('problem', 'easily'), 10.276171875),
#   (('join', 'join'), 10.2515625),
#   (('well', 'developer'), 10.219999999999999),
#   (('find', 'pattern'), 10.209375),
#   (('pattern', 'solve'), 10.209375),
#   (('help', 'really'), 10.2),
#   (('give', 'knowledge'), 10.153125),
#   (('big', 'tech'), 9.9609375),
#   (('make', 'well'), 9.907916666666665),
#   (('skill', 'choose'), 9.817500000000003),
#   (('also', 'interactive'), 9.743478260869566),
#   (('need', 'master'), 9.495833333333332),
#   (('right', 'datum'), 9.4875),
#   (('java', 'question'), 9.401041666666668),
#   (('level', 'programmer'), 9.375669642857144),
#   (('much', 'help'), 9.352083333333333),
#   (('also', 'see'), 9.204945652173912),
#   (('solve', 'popular'), 9.2),
#   (('experience', 'design'), 9.050892857142857),
#   (('get', 'subscription'), 9.007142857142856),
#   (('problem', 'never'), 8.9859375),
#   (('hence', 'important'), 8.983333333333334),
#   (('also', 'check'), 8.966304347826087),
#   (('set', 'good'), 8.963602941176472),
#   (('knowledge', 'practice'), 8.95640625),
#   (('much', 'experience'), 8.941666666666666),
#   (('practice', 'get'), 8.743660714285713),
#   (('book', 'also'), 8.720652173913043),
#   (('also', 'create'), 8.720652173913043),
#   (('dream', 'company'), 8.621130952380952),
#   (('lot', 'computer'), 8.614285714285714),
#   (('access', 'online'), 8.61125),
#   (('experience', 'skill'), 8.53125),
#   (('know', 'include'), 8.52951388888889),
#   (('developer', 'look'), 8.490773809523809),
#   (('graduate', 'look'), 8.474583333333333),
#   (('eventually', 'solve'), 8.4375),
#   (('lack', 'knowledge'), 8.43359375),
#   (('big', 'small'), 8.409375),
#   (('know', 'technique'), 8.375),
#   (('programmer', 'apply'), 8.33720238095238),
#   (('article', 'share'), 8.333333333333332),
#   (('language', 'datum'), 8.3),
#   (('problem', 'use'), 8.28984375),
#   (('need', 'free'), 8.2875),
#   (('recommend', 'take'), 8.26875),
#   (('membership', 'get'), 8.196428571428571),
#   (('important', 'data'), 8.194444444444445),
#   (('need', 'membership'), 8.184375000000001),
#   (('find', 'many'), 8.18125),
#   (('work', 'programmer'), 8.17142857142857),
#   (('know', 'improvement'), 8.166666666666668),
#   (('really', 'like'), 8.133125000000001),
#   (('textbook', 'programming'), 8.113920454545456),
#   (('programming', 'certainly'), 8.113920454545456),
#   (('luck', 'programming'), 8.113920454545456),
#   (('many', 'developer'), 8.077142857142857),
#   (('ready', 'solve'), 8.065625),
#   (('prepare', 'udemy'), 8.01818181818182),
#   (('prepare', 'mock'), 8.01818181818182),
#   (('package', 'prepare'), 8.01818181818182),
#   (('possible', 'prepare'), 8.01818181818182),
#   (('system', 'design'), 8.017559523809522),
#   (('design', 'system'), 8.017559523809522),
#   (('base', 'experience'), 8.0),
#   (('job', 'subject'), 7.853260869565217),
#   (('job', 'afford'), 7.853260869565217),
#   (('analyze', 'algorithm'), 7.809374999999999),
#   (('lot', 'easy'), 7.8080357142857135),
#   (('programmer', 'particularly'), 7.770982142857143),
#   (('particularly', 'programmer'), 7.770982142857143),
#   (('deal', 'system'), 7.752083333333334),
#   (('easily', 'solve'), 7.7),
#   (('solve', 'list'), 7.65),
#   (('solve', 'common'), 7.637499999999999),
#   (('level', 'important'), 7.432118055555556),
#   (('sometimes', 'need'), 7.421875),
#   (('developer', 'dream'), 7.419047619047619),
#   (('analyze', 'problem'), 7.3531249999999995),
#   (('find', 'data'), 7.3500000000000005),
#   (('software', 'engineer'), 7.198660714285714),
#   (('science', 'dream'), 7.196666666666666),
#   (('camp', 'computer'), 7.196666666666666),
#   (('chance', 'need'), 7.145833333333332),
#   (('get', 'chance'), 7.096577380952381),
#   (('technique', 'solve'), 7.091666666666667),
#   (('like', 'teach'), 7.03125),
#   (('graduate', 'junior'), 7.01375),
#   (('problem', 'break'), 6.960546875),
#   (('break', 'problem'), 6.960546875),
#   (('solve', 'similar'), 6.9),
#   (('deal', 'attend'), 6.845833333333333),
#   (('teach', 'data'), 6.834375),
#   (('preparation', 'solve'), 6.824999999999999),
#   (('share', 'lot'), 6.7714285714285705),
#   (('dream', 'make'), 6.76875),
#   (('eventually', 'make'), 6.716666666666666),
#   (('technique', 'find'), 6.708333333333333),
#   (('check', 'list'), 6.458333333333333),
#   (('know', 'author'), 6.4461805555555545),
#   (('require', 'know'), 6.4461805555555545),
#   (('start', 'preparation'), 6.3375),
#   (('important', 'success'), 6.227777777777778),
#   (('easily', 'make'), 6.145833333333333),
#   (('know', 'break'), 6.120833333333334),
#   (('remember', 'choose'), 6.075),
#   (('especially', 'much'), 6.041666666666666),
#   (('coding', 'pattern'), 6.0),
#   (('topic', 'development'), 5.996875000000001),
#   (('many', 'junior'), 5.914999999999999),
#   (('useful', 'developer'), 5.803571428571429),
#   (('write', 'problem'), 5.783203125),
#   (('lot', 'practice'), 5.772321428571429),
#   (('right', 'data'), 5.76875),
#   (('learn', 'bind'), 5.600347222222222),
#   (('learn', 'tackle'), 5.600347222222222),
#   (('learn', 'implement'), 5.600347222222222),
#   (('learn', 'several'), 5.600347222222222),
#   (('learn', 'major'), 5.600347222222222),
#   (('learn', 'approach'), 5.600347222222222),
#   (('machine', 'learn'), 5.600347222222222),
#   (('easy', 'especially'), 5.592708333333333),
#   (('developer', 'apply'), 5.504761904761905),
#   (('like', 'boot'), 5.442708333333333),
#   (('technique', 'many'), 5.432916666666667),
#   (('never', 'easy'), 5.316666666666666),
#   (('engineer', 'graduate'), 5.285),
#   (('hard', 'thing'), 5.146875),
#   (('find', 'educative'), 5.11875),
#   (('lack', 'experience'), 5.0625),
#   (('put', 'good'), 5.032720588235294),
#   (('good', 'effort'), 5.032720588235294),
#   (('good', 'introduction'), 5.032720588235294),
#   (('good', 'sample'), 5.032720588235294),
#   (('good', 'representation'), 5.032720588235294),
#   (('good', 'luck'), 5.032720588235294),
#   (('language', 'give'), 4.987500000000001),
#   (('java', 'developer'), 4.954464285714286),
#   (('preparation', 'list'), 4.916666666666666),
#   (('also', 'reduce'), 4.879347826086957),
#   (('also', 'consider'), 4.879347826086957),
#   (('also', 'blaze'), 4.879347826086957),
#   (('also', 'negotiation'), 4.879347826086957),
#   (('also', 'overview'), 4.879347826086957),
#   (('also', 'practical'), 4.879347826086957),
#   (('also', 'essential'), 4.879347826086957),
#   (('also', 'discuss'), 4.879347826086957),
#   (('spot', 'also'), 4.879347826086957),
#   (('cost', 'also'), 4.879347826086957),
#   (('alternatively', 'also'), 4.879347826086957),
#   (('engineer', 'look'), 4.783333333333333),
#   (('free', 'access'), 4.76),
#   (('lot', 'website'), 4.74375),
#   (('author', 'teach'), 4.55),
#   (('ask', 'experience'), 4.55),
#   (('several', 'dynamic'), 4.515625),
#   (('structure', 'drastically'), 4.504687499999999),
#   (('small', 'similar'), 4.5),
#   (('resume', 'much'), 4.491666666666666),
#   (('question', 'manner'), 4.429761904761905),
#   (('question', 'early'), 4.429761904761905),
#   (('question', 'expect'), 4.429761904761905),
#   (('read', 'question'), 4.429761904761905),
#   (('tricky', 'question'), 4.429761904761905),
#   (('answer', 'question'), 4.429761904761905),
#   (('discuss', 'question'), 4.429761904761905),
#   (('hard', 'advance'), 4.35625),
#   (('skill', 'impress'), 4.35),
#   (('small', 'level'), 4.331250000000001),
#   (('list', 'start'), 4.316666666666666),
#   (('like', 'article'), 4.296875),
#   (('give', 'lack'), 4.196875),
#   (('use', 'technique'), 4.1413690476190474),
#   (('want', 'check'), 4.071428571428571),
#   (('available', 'popular'), 4.05),
#   (('platform', 'useful'), 4.05),
#   (('collection', 'common'), 4.0),
#   (('algorithm', 'building'), 3.9421874999999997),
#   (('enough', 'knowledge'), 3.9382812499999997),
#   (('refresh', 'knowledge'), 3.9382812499999997),
#   (('exist', 'knowledge'), 3.9382812499999997),
#   (('set', 'lot'), 3.925),
#   (('level', 'level'), 3.90625),
#   (('similar', 'previous'), 3.8062500000000004),
#   (('thing', 'profile'), 3.78125),
#   (('programmer', 'clear'), 3.7785714285714285),
#   (('programmer', 'neglect'), 3.7785714285714285),
#   (('probably', 'programmer'), 3.7785714285714285),
#   (('educative', 'platform'), 3.6999999999999997),
#   (('life', 'need'), 3.675),
#   (('need', 'put'), 3.675),
#   (('need', 'flexibility'), 3.675),
#   (('site', 'need'), 3.675),
#   (('system', 'website'), 3.675),
#   (('negotiate', 'need'), 3.675),
#   (('btw', 'need'), 3.675),
#   (('fail', 'hence'), 3.6125),
#   (('see', 'list'), 3.6100000000000003),
#   (('similar', 'kind'), 3.609375),
#   (('honest', 'get'), 3.5361607142857143),
#   (('get', 'unlimited'), 3.5361607142857143),
#   (('get', 'full'), 3.5361607142857143),
#   (('get', 'discount'), 3.5361607142857143),
#   (('guidance', 'get'), 3.5361607142857143),
#   (('consider', 'get'), 3.5361607142857143),
#   (('encourage', 'get'), 3.5361607142857143),
#   (('use', 'different'), 3.441071428571428),
#   (('complexity', 'level'), 3.4375),
#   (('software', 'architect'), 3.4321428571428574),
#   (('software', 'engineering'), 3.4321428571428574),
#   (('use', 'start'), 3.415178571428571),
#   (('major', 'datum'), 3.3843750000000004),
#   (('core', 'datum'), 3.3843750000000004),
#   (('problem', 'recognize'), 3.378515625),
#   (('problem', 'derive'), 3.378515625),
#   (('problem', 'cover'), 3.378515625),
#   (('unknown', 'problem'), 3.378515625),
#   (('complex', 'problem'), 3.378515625),
#   (('think', 'problem'), 3.378515625),
#   (('fast', 'boot'), 3.333333333333333),
#   (('dream', 'work'), 3.314583333333333),
#   (('obvious', 'know'), 3.211111111111111),
#   (('know', 'successfully'), 3.211111111111111),
#   (('apply', 'next'), 3.208333333333333),
#   (('difficult', 'topic'), 3.16875),
#   (('website', 'practice'), 3.006666666666667),
#   (('company', 'honest'), 3.003571428571428),
#   (('company', 'startup'), 3.003571428571428),
#   (('company', 'faang'), 3.003571428571428),
#   (('faang', 'company'), 3.003571428571428),
#   (('complexity', 'improvement'), 3.003125),
#   (('share', 'friend'), 2.9166666666666665),
#   (('example', 'use'), 2.9142857142857146),
#   (('fast', 'use'), 2.9142857142857146),
#   (('single', 'important'), 2.8444444444444446),
#   (('important', 'reason'), 2.8444444444444446),
#   (('increasingly', 'important'), 2.8444444444444446),
#   (('focused', 'important'), 2.8444444444444446),
#   (('overview', 'important'), 2.8444444444444446),
#   (('especially', 'short'), 2.8125),
#   (('language', 'require'), 2.7749999999999995),
#   (('really', 'interested'), 2.7612500000000004),
#   (('become', 'well'), 2.7612500000000004),
#   (('becuase', 'really'), 2.7612500000000004),
#   (('like', 'book'), 2.73125),
#   (('pattern', 'develop'), 2.709375),
#   (('pattern', 'third'), 2.709375),
#   (('recognize', 'pattern'), 2.709375),
#   (('furthermore', 'choose'), 2.645),
#   (('available', 'subscription'), 2.628125),
#   (('break', 'small'), 2.628125),
#   (('join', 'ideal'), 2.562890625),
#   (('flexibility', 'join'), 2.562890625),
#   (('website', 'application'), 2.552083333333333),
#   (('option', 'online'), 2.53125),
#   (('online', 'training'), 2.53125),
#   (('design', 'new'), 2.508035714285714),
#   (('design', 'college'), 2.508035714285714),
#   (('database', 'design'), 2.508035714285714),
#   (('mind', 'design'), 2.508035714285714),
#   (('architect', 'design'), 2.508035714285714),
#   (('specially', 'design'), 2.508035714285714),
#   (('drastically', 'improve'), 2.5),
#   (('improve', 'cpu'), 2.5),
#   (('sometimes', 'hard'), 2.5),
#   (('friend', 'colleague'), 2.5),
#   (('late', 'topic'), 2.4937500000000004),
#   (('hunt', 'first'), 2.4499999999999997),
#   (('use', 'set'), 2.41875),
#   (('never', 'see'), 2.40125),
#   (('effort', 'find'), 2.3999999999999995),
#   (('find', 'huge'), 2.3999999999999995),
#   (('expensive', 'computer'), 2.3112500000000002),
#   (('college', 'graduate'), 2.3112500000000002),
#   (('help', 'totally'), 2.26875),
#   (('help', 'achieve'), 2.26875),
#   (('skill', 'become'), 2.25625),
#   (('kind', 'java'), 2.21875),
#   (('profile', 'application'), 2.21875),
#   (('solve', 'complex'), 2.1875),
#   (('solve', 'individual'), 2.1875),
#   (('end', 'article'), 2.1875),
#   (('try', 'solve'), 2.1875),
#   (('make', 'large'), 2.1333333333333333),
#   (('make', 'final'), 2.1333333333333333),
#   (('example', 'apply'), 2.1333333333333333),
#   (('one', 'fantastic'), 2.1333333333333333),
#   (('experienced', 'one'), 2.1333333333333333),
#   (('discount', 'link'), 2.1254464285714283),
#   (('concept', 'link'), 2.1254464285714283),
#   (('teach', 'aspect'), 2.109375),
#   (('teach', 'style'), 2.109375),
#   (('want', 'instead'), 2.057142857142857),
#   (('want', 'brush'), 2.057142857142857),
#   (('want', 'translate'), 2.057142857142857),
#   (('post', 'want'), 2.057142857142857),
#   (('forget', 'want'), 2.057142857142857),
#   (('kind', 'interactive'), 2.0541666666666663),
#   (('development', 'machine'), 2.002083333333333),
#   (('experience', 'answer'), 2.0),
#   (('thankfully', 'lot'), 1.9723214285714286),
#   (('apply', 'java'), 1.9541666666666666),
#   (('technology', 'relate'), 1.953125),
#   (('impress', 'interviewer'), 1.953125),
#   (('look', 'core'), 1.9260416666666667),
#   (('easy', 'follow'), 1.9260416666666667),
#   (('certainly', 'easy'), 1.9260416666666667),
#   (('large', 'tech'), 1.9140625),
#   (('tech', 'giant'), 1.9140625),
#   (('top', 'tech'), 1.9140625),
#   (('work', 'see'), 1.8987500000000002),
#   (('see', 'example'), 1.87),
#   (('memory', 'profile'), 1.828125),
#   (('access', 'future'), 1.8050000000000002),
#   (('full', 'access'), 1.8050000000000002),
#   (('remember', 'resume'), 1.8),
#   (('base', 'exist'), 1.7999999999999998),
#   (('com', 'ready'), 1.796875),
#   (('chance', 'see'), 1.7462499999999999),
#   (('many', 'hour'), 1.7112500000000002),
#   (('spend', 'many'), 1.7112500000000002),
#   (('thing', 'life'), 1.7015624999999999),
#   (('thing', 'change'), 1.7015624999999999),
#   (('thing', 'keep'), 1.7015624999999999),
#   (('introduction', 'thing'), 1.7015624999999999),
#   (('sense', 'must'), 1.653125),
#   (('right', 'way'), 1.53125),
#   (('giant', 'right'), 1.53125),
#   (('last', 'year'), 1.5125),
#   (('add', 'platform'), 1.5125),
#   (('list', 'collect'), 1.5041666666666667),
#   (('resume', 'chance'), 1.45),
#   (('often', 'give'), 1.4260416666666667),
#   (('give', 'top'), 1.4260416666666667),
#   (('beginner', 'give'), 1.4260416666666667),
#   (('solution', 'give'), 1.4260416666666667),
#   (('new', 'system'), 1.4083333333333332),
#   (('profile', 'impress'), 1.378125),
#   (('camp', 'methodology'), 1.3020833333333333),
#   (('hence', 'increasingly'), 1.25),
#   (('part', 'eventually'), 1.25),
#   (('methodology', 'focus'), 1.128125),
#   (('focus', 'rigorous'), 1.128125),
#   (('focus', 'attention'), 1.128125),
#   (('provide', 'similar'), 1.05625),
#   (('next', 'project'), 1.0125),
#   (('attend', 'couple'), 1.0125),
#   (('negotiation', 'easily'), 1.0125),
#   (('practice', 'bit'), 0.98),
#   (('rigorous', 'practice'), 0.98),
#   (('use', 'less'), 0.9723214285714284),
#   (('use', 'watch'), 0.9723214285714284),
#   (('implement', 'use'), 0.9723214285714284),
#   (('fact', 'hard'), 0.91875),
#   (('hard', 'beginner'), 0.91875),
#   (('include', 'experienced'), 0.903125),
#   (('write', 'write'), 0.8999999999999999),
#   (('huge', 'collection'), 0.8),
#   (('article', 'blog'), 0.78125),
#   (('republish', 'article'), 0.78125),
#   (('application', 'app'), 0.7520833333333333),
#   (('application', 'everywhere'), 0.7520833333333333),
#   (('block', 'application'), 0.7520833333333333),
#   (('representation', 'kind'), 0.7520833333333333),
#   (('interviewer', 'respect'), 0.703125),
#   (('respect', 'complexity'), 0.703125),
#   (('subscription', 'annual'), 0.703125),
#   (('start', 'scratch'), 0.6749999999999999),
#   (('free', 'resource'), 0.6749999999999999),
#   (('reason', 'fail'), 0.6124999999999999),
#   (('bind', 'fail'), 0.6124999999999999),
#   (('different', 'academy'), 0.6124999999999999),
#   (('different', 'area'), 0.6124999999999999),
#   (('short', 'duration'), 0.6124999999999999),
#   (('overall', 'complete'), 0.6020833333333333),
#   (('buying', 'overall'), 0.6020833333333333),
#   (('apply', 'program'), 0.6020833333333333),
#   (('cpu', 'memory'), 0.5333333333333333),
#   (('low', 'memory'), 0.5333333333333333),
#   (('less', 'memory'), 0.5333333333333333),
#   (('website', 'publication'), 0.5333333333333333),
#   (('blog', 'website'), 0.5333333333333333),
#   (('clear', 'difficult'), 0.528125),
#   (('coding', 'medium'), 0.528125),
#   (('fresh', 'engineer'), 0.528125),
#   (('membership', 'encourage'), 0.528125),
#   (('program', 'coding'), 0.528125),
#   (('example', 'phone'), 0.46875),
#   (('fast', 'low'), 0.46875),
#   (('run', 'fast'), 0.46875),
#   (('actual', 'example'), 0.46875),
#   (('educative', 'gain'), 0.46875),
#   (('blaze', 'fast'), 0.46875),
#   (('see', 'actual'), 0.45125000000000004),
#   (('see', 'evaluate'), 0.45125000000000004),
#   (('offer', 'negotiate'), 0.44999999999999996),
#   (('final', 'offer'), 0.44999999999999996),
#   (('key', 'success'), 0.44999999999999996),
#   (('spoil', 'chance'), 0.40833333333333327),
#   (('author', 'spend'), 0.378125),
#   (('information', 'require'), 0.378125),
#   (('dealing', 'sometimes'), 0.378125),
#   (('interactive', 'guidance'), 0.3125),
#   (('interactive', 'quiz'), 0.3125),
#   (('impress', 'recruit'), 0.3125),
#   (('end', 'able'), 0.3125),
#   (('great', 'resume'), 0.3125),
#   (('collect', 'friend'), 0.3125),
#   (('thank', 'end'), 0.3125),
#   (('colleague', 'forget'), 0.3125),
#   (('little', 'late'), 0.29999999999999993),
#   (('late', 'spoil'), 0.29999999999999993),
#   (('late', 'certification'), 0.29999999999999993),
#   (('exercise', 'late'), 0.29999999999999993),
#   (('resource', 'check'), 0.29999999999999993),
#   (('able', 'write'), 0.22499999999999998),
#   (('guide', 'write'), 0.22499999999999998),
#   (('relation', 'write'), 0.22499999999999998),
#   (('dedicate', 'book'), 0.2),
#   (('create', 'former'), 0.2),
#   (('create', 'great'), 0.2),
#   (('around', 'month'), 0.078125),
#   (('month', 'annually'), 0.078125),
#   (('com', 'usually'), 0.07499999999999998)])
